# %%
import numpy as np

# %%
load_RMSE = np.load('RMSE_list.npy')
load_parameters = np.load('parameters_list.npy')

# %%
load_RMSE
# Out:
# array([1.45708789, 1.52034175, 1.45651412, 1.4957323 , 1.50831777,
#        1.44035868, 1.41814407, 1.47244417, 1.42711816, 1.45786169,
#        1.52131038, 1.45699866, 1.49635492, 1.50892965, 1.44016243,
#        1.41804727, 1.47282578, 1.42773901, 1.40116015, 1.52718536,
#        1.47058628, 1.45427844, 1.50124568, 1.42881159, 1.41921588,
#        1.46583653, 1.43430839, 1.40316207, 1.52799553, 1.47116883,
#        1.45473473, 1.5016136 , 1.42898258, 1.41924589, 1.46591828,
#        1.43434224, 1.3055795 , 1.35702736, 1.30759117, 1.42335004,
#        1.45433359, 1.42211839, 1.42004472, 1.43834957, 1.43182449,
#        1.3055795 , 1.35702736, 1.30759117, 1.42335004, 1.45433359,
#        1.42211839, 1.42004472, 1.43834957, 1.43182449, 1.20590939,
#        1.23561528, 1.20591837, 1.41373819, 1.41427462, 1.39937423,
#        1.44364764, 1.46174337, 1.4505831 , 1.20526633, 1.23710964,
#        1.20463069, 1.41962972, 1.41855879, 1.40542657, 1.44862697,
# ...

# %%
len(load_parameters)
# Out:
# 360
